# %% [markdown]
# # Exploration base de données graphe

# %%
import pandas as pd

# %%
df = pd.read_csv("20230106100009_observatoire_2g_3g_4g.csv",sep = ";")
print(len(df))
print(df.columns)
df.head()
# Out:
# 656764
# Index(['id', 'adm_lb_nom', 'sup_id', 'emr_lb_systeme', 'emr_dt', 'sta_nm_dpt',
#        'code_insee', 'generation', 'date_maj', 'sta_nm_anfr', 'nat_id',
#        'sup_nm_haut', 'tpo_id', 'adr_lb_lieu', 'adr_lb_add1', 'adr_lb_add2',
#        'adr_lb_add3', 'adr_nm_cp', 'com_cd_insee', 'coordonnees', 'coord',
#        'statut'],
#       dtype='object')
#    id adm_lb_nom  sup_id emr_lb_systeme      emr_dt sta_nm_dpt code_insee  \
# 0   1        SFR  440000        GSM 900  2008-12-19        091      91137
# 1   2        SFR  440000        LTE 800  2016-12-16        091      91137
# 2   3        SFR  440000       UMTS 900  2016-12-12        091      91137
# 3   4        SFR  440000      UMTS 2100  2011-10-04        091      91137
# 4   5        SFR   81600        GSM 900  2016-05-25        060      60517
#
#   generation    date_maj sta_nm_anfr  ...  tpo_id          adr_lb_lieu  \
# 0         2G  2023-01-04  0912700030  ...    65.0  LE CHÂTEAU GAILLARD
# ...

# %%
get_values_set("sta_nm_anfr")
# Out:
# 114264

# %%
def get_values_set(attribute):
    set_ =  set(df[attribute].values)
    l = len(set_)
    print(l)
    if l<=50 :
        print(set_)

# %%
for col in df.columns:
    print(col)
    get_values_set(col)
    print("--------------------------------------")
# Out:
# id
# 656764
# --------------------------------------
# adm_lb_nom
# 21
# {'ONATI', 'SRR', 'FREE CARAIBES', 'TELCO OI', 'UTS Caraibes', 'VITI SAS', 'SPT', 'FREE MOBILE', 'ZEOP', 'MAORE MOBILE', 'DAUPHIN TELECOM', 'PMT/VODAFONE', 'GLOBALTEL', 'DIGICEL', 'Gouv Nelle Calédonie (OPT)', 'SPM TELECOM', 'BOUYGUES TELECOM', 'ORANGE', 'SFR', 'OUTREMER TELECOM', 'Station étrangère'}
# --------------------------------------
# sup_id
# 63279
# --------------------------------------
# emr_lb_systeme
# 14
# {'LTE 1800', 'LTE 800', 'GSM 900', 'GSM 1800', '5G NR 2100', 'UMTS 2100', 'LTE 2100', '5G NR 700', 'LTE 900', 'LTE 700', '5G NR 3500', 'LTE 2600', 'UMTS 900', '5G NR 1800'}
# --------------------------------------
# emr_dt
# 8558
# --------------------------------------
# sta_nm_dpt
# 107
# --------------------------------------
# code_insee
# 20126
# --------------------------------------
# generation
# 4
# {'4G', '3G', '5G', '2G'}
# --------------------------------------
# date_maj
# 1
# ...

# %%
set(df['code_insee']==df["com_cd_insee"])
# Out:
# {True}
